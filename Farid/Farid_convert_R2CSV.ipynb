# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/Advance-Statistical-Learnin--Semester-3/blob/main/Farid/Farid_convert_R2CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FaridRash/Advance-Statistical-Learnin--Semester-3
# Out:
# Cloning into 'Advance-Statistical-Learnin--Semester-3'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 101 (delta 21), reused 23 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 43.98 MiB | 11.33 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pip install pyreadr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.7/411.7 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import pyreadr

result = pyreadr.read_r("/content/Advance-Statistical-Learnin--Semester-3/Dataset/df_sla_st 3.Rdata")

# Show all object names in the file
print(result.keys())
# Out:
# odict_keys(['df_sla'])

# %%
df = result['df_sla']
print(df.head())
# Out:
#    Patient_ID  Visit_ID Date_of_birth Symptom_onset_date Diagnosis_date Sex  \
# 0           1         1    1941-06-22         2018-10-01     2019-12-12   0
# 1           1         2    1941-06-22         2018-10-01     2019-12-12   0
# 2           1         3    1941-06-22         2018-10-01     2019-12-12   0
# 3           1         4    1941-06-22         2018-10-01     2019-12-12   0
# 4           1         5    1941-06-22         2018-10-01     2019-12-12   0
#
#    Age_at_onset Clinical_onset_type Spirometry    FVC  ...  MRC_Bulbar  \
# 0          77.0             spinale          1    >80  ...        11.0
# 1          77.0             spinale          1  60-80  ...        13.0
# 2          77.0             spinale         NA     ND  ...        12.0
# 3          77.0             spinale          1  40-60  ...        12.0
# 4          77.0             spinale         NA     ND  ...        11.0
#
#   PUMNS_Upper_Limb  PUMNS_Lower_Limb  PUMNS_Bulbar CNS_Linear_Score  \
# ...

# %%
display(df.head())
# Out:
#    Patient_ID  Visit_ID Date_of_birth Symptom_onset_date Diagnosis_date Sex  \
# 0           1         1    1941-06-22         2018-10-01     2019-12-12   0
# 1           1         2    1941-06-22         2018-10-01     2019-12-12   0
# 2           1         3    1941-06-22         2018-10-01     2019-12-12   0
# 3           1         4    1941-06-22         2018-10-01     2019-12-12   0
# 4           1         5    1941-06-22         2018-10-01     2019-12-12   0
#
#    Age_at_onset Clinical_onset_type Spirometry    FVC  ...  MRC_Bulbar  \
# 0          77.0             spinale          1    >80  ...        11.0
# 1          77.0             spinale          1  60-80  ...        13.0
# 2          77.0             spinale         NA     ND  ...        12.0
# 3          77.0             spinale          1  40-60  ...        12.0
# 4          77.0             spinale         NA     ND  ...        11.0
#
#   PUMNS_Upper_Limb  PUMNS_Lower_Limb  PUMNS_Bulbar CNS_Linear_Score  \
# ...

# %%
from google.colab import files

# Save the DataFrame to a CSV file
df.to_csv('df_sla.csv', index=False)

# Provide a link to download the file
files.download('df_sla.csv')
