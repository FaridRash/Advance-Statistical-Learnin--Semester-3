# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/Advance-Statistical-Learnin--Semester-3/blob/main/Farid/Farid_Multilevel_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Git

# %%
# !git clone https://github.com/FaridRash/Advance-Statistical-Learnin--Semester-3
# Out:
# Cloning into 'Advance-Statistical-Learnin--Semester-3'...
# remote: Enumerating objects: 537, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 537 (delta 105), reused 11 (delta 11), pack-reused 373 (from 2)
# Receiving objects: 100% (537/537), 57.70 MiB | 8.16 MiB/s, done.
# Resolving deltas: 100% (262/262), done.

# %% [markdown]
# #Data Reading

# %%
df = pd.read_csv('/content/Advance-Statistical-Learnin--Semester-3/Dataset/df_Final.csv')
display(df.head())
# Out:
#    Patient_ID  Visit_ID  Sex  Age_at_onset Clinical_onset_type  Spirometry  \
# 0         133         3    0          19.0             spinale         1.0
# 1          79         1    0          65.0             spinale         1.0
# 2          81         1    1          79.0             bulbare         1.0
# 3         214         1    0          51.0             spinale         1.0
# 4         214         2    0          51.0             spinale         1.0
#
#      FVC  Ventilation  Tracheostomy  PEG  ... MRC_Bulbar  PUMNS_Upper_Limb  \
# 0    >80          0.0             0  0.0  ...       14.0               0.0
# 1  40-60          0.0             0  0.0  ...       13.0               1.0
# 2    >80          0.0             0  0.0  ...       11.0               4.0
# 3    >80          0.0             0  0.0  ...       15.0               0.0
# 4    >80          0.0             0  0.0  ...       15.0               0.0
#
#    PUMNS_Lower_Limb  PUMNS_Bulbar  CNS_Linear_Score  KINGS_Total  \
# 0               6.0           0.0               7.0            1
# 1               4.0           3.0              15.0            1
# 2               4.0           2.0               7.0            1
# 3               0.0           0.0               7.0            1
# 4               0.0           0.0               7.0            1
#
#    Disease_duration  Progression_rate  ALSFRS_R  ALSAQ_5
# 0              40.0          0.075000      45.0      0.0
# 1              14.0          0.714286      38.0     15.0
# 2               6.0          0.833333      43.0     20.0
# 3              20.0          0.200000      44.0     20.0
# 4              23.0          0.130435      45.0     25.0
#
# [5 rows x 24 columns]
